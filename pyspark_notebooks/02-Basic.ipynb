# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!

# %%
df = spark.sql("SELECT * FROM ExploreLakeHouse.sales LIMIT 1000")
display(df)
# Out:
# StatementMeta(, d3494d8a-6998-470c-a6d9-279f360037fb, 3, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, d95efee4-e59d-4893-abbc-f1792c627d2e)
